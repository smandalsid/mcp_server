# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
web_search_schema = {
    "type": "web_search_20250305",
    "name": "web_search",
    "max_uses": 5,
    "allowed_domains": ["nih.gov"]
}

# %%
messages = []
add_user_message(
    messages,
    """
    whats the best exercise for gaining leg muscle?
    """,
)
response = chat(messages, tools=[web_search_schema])
response
# Out:
# Message(id='msg_014bSyqFptKTaxiqwQjLe9tF', container=None, content=[TextBlock(citations=None, text='The best exercises for gaining leg muscle typically include:\n\n**Compound movements:**\n- **Squats** (barbell back squats, front squats) - Often considered the king of leg exercises, they work the quadriceps, hamstrings, glutes, and calves\n- **Deadlifts** (conventional, Romanian, or stiff-legged) - Excellent for hamstrings, glutes, and overall posterior chain development\n- **Lunges** (walking, reverse, or stationary) - Great for quads, glutes, and balance\n- **Leg Press** - Allows heavy loading with less technical demand than squats\n\n**Isolation exercises:**\n- **Leg Extensions** - Targets quadriceps\n- **Leg Curls** - Isolates hamstrings\n- **Calf Raises** - For calf development\n\n**Key principles for muscle growth:**\n- **Progressive overload** - Gradually increase weight, reps, or volume over time\n- **Training volume** - Multiple sets (typically 3-5) with 6-12 reps for hypertrophy\n- **Proper form** - Ensures muscle engagement and reduces injury risk\n- **Recovery** - Allow 48-72 hours between intense leg sessions\n- **Nutrition** - Adequate protein intake (0.7-1g per pound of bodyweight) and caloric surplus\n\n**The "best" exercise depends on:**\n- Your experience level\n- Available equipment\n- Any injuries or limitations\n- Individual biomechanics\n\nFor most people, **barbell squats and Romanian deadlifts** form an excellent foundation for leg muscle development, as they recruit the most muscle mass and allow for progressive overload. However, a well-rounded program incorporating multiple movements will yield the best results.', type='text')], model='claude-sonnet-4-5-20250929', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=2228, output_tokens=399, server_tool_use=None, service_tier='standard'))
